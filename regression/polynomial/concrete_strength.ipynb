# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("concrete_data.csv")
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.tail()
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 1025             870.1           768.3   28     44.28
# 1026             817.9           813.4   28     31.18
# 1027             892.4           780.0   28     23.70
# 1028             989.6           788.9   28     32.77
# 1029             864.5           761.5   28     32.40

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Cement                float64
# Blast Furnace Slag    float64
# Fly Ash               float64
# Water                 float64
# Superplasticizer      float64
# Coarse Aggregate      float64
# Fine Aggregate        float64
# Age                     int64
# Strength              float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age
# 0               1040.0           676.0   28
# 1               1055.0           676.0   28
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       79.99
# 1       61.89
# 2       40.27
# 3       41.05
# 4       44.30
#         ...
# 1025    44.28
# 1026    31.18
# 1027    23.70
# 1028    32.77
# 1029    32.40
# Name: Strength, Length: 1030, dtype: float64

# %%
#scatter plot btw cement and strength
plt.scatter(x["Cement"],y,color="k")
plt.xlabel("Cement")
plt.ylabel("Strength")
plt.title("Cement vs strength graph")
# Out:
# Text(0.5, 1.0, 'Cement vs strength graph')

# %%
#scatter plot btw blast furnace slag and strength
plt.scatter(x["Blast Furnace Slag"],y,color="g")
plt.xlabel("Blast Furnace Slag")
plt.ylabel("Strength")
plt.title("Blast Furnace Slag vs strength graph")
# Out:
# Text(0.5, 1.0, 'Blast Furnace Slag vs strength graph')

# %%
#scatter plot btw fly ash and strength
plt.scatter(x["Fly Ash"],y,color="b")
plt.xlabel("Fly Ash")
plt.ylabel("Strength")
plt.title("Fly Ash vs strength graph")
# Out:
# Text(0.5, 1.0, 'Fly Ash vs strength graph')

# %%
#scatter plot btw water and strength
plt.scatter(x["Water"],y,color="c")
plt.xlabel("Water")
plt.ylabel("Strength")
plt.title("Water vs strength graph")
# Out:
# Text(0.5, 1.0, 'Water vs strength graph')

# %%
#scatter plot btw superplasticizer and strength
plt.scatter(x["Superplasticizer"],y,color="m")
plt.xlabel("Superplasticizer")
plt.ylabel("Strength")
plt.title("superplasticizer vs strength graph")
# Out:
# Text(0.5, 1.0, 'superplasticizer vs strength graph')

# %%
#scatter plot btw coarse Aggregate and strength
plt.scatter(x["Coarse Aggregate"],y,color="y")
plt.xlabel("Coarse Aggregate")
plt.ylabel("Strength")
plt.title("Coarse aggregate vs strength graph")
# Out:
# Text(0.5, 1.0, 'Coarse aggregate vs strength graph')

# %%
#scatter plot btw fine aggregate and strength
plt.scatter(x["Fine Aggregate"],y,color="r")
plt.xlabel("Fine aggregate")
plt.ylabel("Strength")
plt.title("Fine Aggregate vs strength graph")
# Out:
# Text(0.5, 1.0, 'Fine Aggregate vs strength graph')

# %%
#scatter plot btw age and strength
plt.scatter(x["Age"],y,color="pink")
plt.xlabel("Age")
plt.ylabel("Strength")
plt.title("Age vs strength graph")
# Out:
# Text(0.5, 1.0, 'Age vs strength graph')

# %%
#regression plot 
sns.regplot(x=df["Cement"],y=y,color="k")
# Out:
# <Axes: xlabel='Cement', ylabel='Strength'>

# %%
sns.regplot(x=df["Blast Furnace Slag"],y=y,color="g")
# Out:
# <Axes: xlabel='Blast Furnace Slag', ylabel='Strength'>

# %%
sns.regplot(x=df["Fly Ash"],y=y,color="b")
# Out:
# <Axes: xlabel='Fly Ash', ylabel='Strength'>

# %%
sns.regplot(x=df["Water"],y=y,color="c")
# Out:
# <Axes: xlabel='Water', ylabel='Strength'>

# %%
sns.regplot(x=df["Superplasticizer"],y=y,color="m")
# Out:
# <Axes: xlabel='Superplasticizer', ylabel='Strength'>

# %%
sns.regplot(x=df["Coarse Aggregate"],y=y,color="y")
# Out:
# <Axes: xlabel='Coarse Aggregate', ylabel='Strength'>

# %%
sns.regplot(x=df["Fine Aggregate"],y=y,color="r")
# Out:
# <Axes: xlabel='Fine Aggregate', ylabel='Strength'>

# %%
sns.regplot(x=df["Age"],y=y,color="pink")
# Out:
# <Axes: xlabel='Age', ylabel='Strength'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 772   382.0                 0.0      0.0  186.0               0.0
# 997   310.0               142.8      0.0  167.9              10.0
# 724   310.0                 0.0      0.0  192.0               0.0
# 167   475.0               118.8      0.0  181.1               8.9
# 764   385.0                 0.0      0.0  186.0               0.0
# ..      ...                 ...      ...    ...               ...
# 277   251.4                 0.0    118.3  188.5               5.8
# 763   385.0                 0.0      0.0  186.0               0.0
# 835   144.0                 0.0    175.0  158.0              18.0
# 559   239.6               359.4      0.0  185.7               0.0
# 684   192.0               288.0      0.0  192.0               0.0
#
#      Coarse Aggregate  Fine Aggregate  Age
# 772            1047.0           739.0    7
# 997             914.3           804.0   28
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([39.47333647, 14.08181113, 60.90617502, 53.49216504, 23.95652105,
#        53.38494262, 45.65496577, 26.92130645, 52.88683822, 37.13787653,
#        16.55157144, 38.81020387, 29.47532698, 35.14012862, 47.80046883,
#        56.45734447, 35.43954133, 29.20286434, 48.34810942, 35.12300254,
#        53.44653832, 31.87269795, 32.38089157, 47.90405414, 23.4547955 ,
#        23.32931202, 69.81924352, 26.29647636, 56.45734447, 47.80199424,
#        18.7288124 , 36.32839137, 17.2570425 , 19.75384858, 24.46017771,
#        15.0536384 , 52.94088734, 27.79184471, 26.73627367, 25.95801099,
#        52.51684761, 30.33783679, 26.02387955, 35.01487363, 53.0415329 ,
#        54.01405889, 30.33153322, 43.96402577, 27.4875974 , 56.65557931,
#        36.417551  , 19.18663184, 23.29973858, 34.35993512, 43.00786877,
#        47.19325832, 35.40203995, 52.88814999, 59.89779143, 36.30933765,
#        30.98904611, 20.58209173, 50.33598027, 55.61201479, 20.36535531,
# ...

# %%
y_test
# Out:
# 747    26.06
# 718    10.35
# 175    79.30
# 828    74.99
# 713     9.69
#        ...
# 156    72.99
# 222    28.63
# 665    11.39
# 210    20.08
# 306    48.28
# Name: Strength, Length: 309, dtype: float64

# %%
print("Slope is",list(zip(x,model.coef_)))
# Out:
# Slope is [('Cement', np.float64(0.12132219951786499)), ('Blast Furnace Slag', np.float64(0.10790306559516523)), ('Fly Ash', np.float64(0.09202680690494434)), ('Water', np.float64(-0.132512210720988)), ('Superplasticizer', np.float64(0.35446729393993964)), ('Coarse Aggregate', np.float64(0.023773237330165845)), ('Fine Aggregate', np.float64(0.024250200059110907)), ('Age', np.float64(0.1110138214258391))]

# %%
print("constant is",model.intercept_)
# Out:
# constant is -36.62862724393952

# %%
df1=pd.DataFrame({"Actual value":y_test,"Predicted value":y_pred,"Difference":y_test-y_pred})
df1
# Out:
#      Actual value  Predicted value  Difference
# 747         26.06        39.473336  -13.413336
# 718         10.35        14.081811   -3.731811
# 175         79.30        60.906175   18.393825
# 828         74.99        53.492165   21.497835
# 713          9.69        23.956521  -14.266521
# ..            ...              ...         ...
# 156         72.99        54.168415   18.821585
# 222         28.63        27.058369    1.571631
# 665         11.39        15.497694   -4.107694
# 210         20.08        22.309228   -2.229228
# 306         48.28        36.349036   11.930964
#
# [309 rows x 3 columns]

# %%
print(model.predict([[332.5,142.5,0.0,218.0,0.0,922.0,500.0,29]]))
# Out:
# [27.46295468]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 7.7756257101890345

# %%
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.30399656208704356

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 93.61873598596335

# %%
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 9.675677546609506

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.6352987285077927

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(x_train)
X_test_poly = poly.transform(x_test)
X_train_poly
# Out:
# array([[1.0000000e+00, 3.8200000e+02, 0.0000000e+00, ..., 5.4612100e+05,
#         5.1730000e+03, 4.9000000e+01],
#        [1.0000000e+00, 3.1000000e+02, 1.4280000e+02, ..., 6.4641600e+05,
#         2.2512000e+04, 7.8400000e+02],
#        [1.0000000e+00, 3.1000000e+02, 0.0000000e+00, ..., 6.8890000e+05,
#         7.4700000e+04, 8.1000000e+03],
#        ...,
#        [1.0000000e+00, 1.4400000e+02, 0.0000000e+00, ..., 7.1233600e+05,
#         2.3632000e+04, 7.8400000e+02],
#        [1.0000000e+00, 2.3960000e+02, 3.5940000e+02, ..., 4.4129449e+05,
#         1.8600400e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.9200000e+02, 2.8800000e+02, ..., 5.1279921e+05,
#         6.4449000e+04, 8.1000000e+03]], shape=(721, 45))

# %%
model1=LinearRegression()
model1.fit(X_train_poly,y_train)
y_pred1=model1.predict(X_test_poly)
y_pred1
# Out:
# array([34.87917021, 11.19388536, 77.35308616, 55.16350403, 15.9615508 ,
#        57.36824756, 50.73726784, 23.80807663, 60.85379977, 49.541905  ,
#        15.80496552, 50.93871375, 32.94502626, 23.27983736, 55.80632633,
#        68.51187726, 30.049135  , 36.63565814, 50.5719649 , 33.06972478,
#        59.43915227, 38.41280054, 28.74677975, 49.53100121, 21.8915282 ,
#        23.86671583, 52.5394756 , 24.22581107, 68.51187726, 61.71682688,
#        17.66634031, 44.53047741, 19.85982908, 29.53785187, 23.47960785,
#         9.81689889, 56.19618214, 21.37454201, 22.68932566, 22.06060422,
#        47.11277104, 38.86455326, 29.78430501, 34.14201745, 56.26921061,
#        42.29521192, 29.63779745, 41.93711224, 30.24764135, 35.6406097 ,
#        41.00172437, 22.21812959, 27.7700713 , 45.25936902, 58.07425072,
#        46.9816839 , 36.11988238, 58.88907642, 64.34265319, 41.42509403,
#        33.19831156, 15.52821585, 53.33580634, 33.47356198, 16.17583012,
# ...

# %%
print(mean_absolute_percentage_error(y_test,y_pred1))
# Out:
# 0.2070888376222069

# %%
print(r2_score(y_test,y_pred1))
# Out:
# 0.758783704531188
