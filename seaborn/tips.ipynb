# %%
import seaborn as sns
import ssl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
ssl._create_default_https_context = ssl._create_unverified_context 
df=sns.load_dataset('tips') #titanic,iris,diamonds,penguin
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#feature selection==> required columns selection
correlation=df.corr(numeric_only=True)
correlation #a correlation matrix is formed , diagional elements are one
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heatmap ==> visualise correlation matrix
sns.heatmap(correlation) # light color ==> strong correlation , dark ==> weak correlation
#cmap="coolwarm" ==> darker==> strong , light==> weak
# Out:
# <Axes: >

# %%
#jointplot ==> numerical values relation
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg")
#right side==> histogram of tip
# top ==> histogram of total_bill
#scatter of both tip and total_bill
#kind="hex" ==> scatter is represented in hexagon shape
# kind="reg" ==> regression plot and distribution pattern of histogram

# %%
#pairplot==> numerical relation of multiple (correlation metrix)
sns.pairplot(df)

# %%
sns.pairplot(df,hue="sex") # hue ==> for specific column (categorical)

# %%
#count plot ==> count of categorical colm
sns.countplot(x="sex",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="day",data=df,hue="smoker") # hue==> condition/parameter
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#bar plot ==> comparison btw numerical and categorical data
sns.barplot(x="total_bill",y="day",data=df)
# black line ==> error bar(longer the bar ==> more variation) 
#ci=None ==>confidence interval (to remove error bar)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x="tip",y="day",data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#box plot ==>find outlier(visualise)
sns.boxplot(x="smoker",y="total_bill",data=df)
#whisker==> line extending from the box
#upper whisker==>maximum value
#lower whisker==> minimum value
#Q1==> 25th percentile(both line of box)
#Q2==> median (middle)
#Q3==> 75th percentile (upper line of box)
#iqr==> inter quartile range(blue box) 
#circles==> outliers
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
df["total_bill"].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
sns.boxplot(y="total_bill",data=df) #outliers are shown above
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y="tip",data=df)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(x="day",y="total_bill",data=df,hue="sex") #x,hue==> categorical y ==> numerical
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="time",y="tip",data=df,hue="smoker")
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
def removal_box_plot(df,column,threshold):
    sns.boxplot(df[column])
    plt.title(f"Original box plot of {column}")
    plt.show()

    removed_outliers=df[df[column]<=threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value=40
no_outliers=removal_box_plot(df,"total_bill",threshold_value)

# %%
# def removal_box_plot(df, column):
#     # Original Box Plot
#     sns.boxplot(y=df[column])
#     plt.title(f'Original Box Plot of {column}')
#     plt.show()

#     # Calculate Q1 (25th percentile) and Q3 (75th percentile)
#     Q1 = df[column].quantile(0.25)
#     Q3 = df[column].quantile(0.75)
#     IQR = Q3 - Q1

#     # Define Outlier Boundaries
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR

#     # Remove Outliers
#     removed_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

#     # Box Plot After Outlier Removal
#     sns.boxplot(y=removed_outliers[column])
#     plt.title(f'Box Plot without Outliers of {column}')
#     plt.show()

#     return removed_outliers

# removal_box_plot(df,"total_bill")

# %%
#scatter 
plt.scatter(df['total_bill'], df['tip'])
plt.xlabel('Total_bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
outlier_indices = np.where((df["total_bill"]>30) & (df["tip"]<6))

no_outliers = df.drop(outlier_indices[0])

plt.scatter(no_outliers["total_bill"], no_outliers["tip"])
plt.xlabel('(body mass index of people)')
plt.ylabel('(bp of the people )')
# Out:
# Text(0, 0.5, '(bp of the people )')

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df['total_bill']))
print(z)
# Out:
# [3.14711305e-01 1.06323531e+00 1.37779900e-01 4.38315103e-01
#  5.40744704e-01 6.19536705e-01 1.23995452e+00 7.98507107e-01
#  5.34203307e-01 5.63468908e-01 1.07111451e+00 1.74175992e+00
#  4.91430507e-01 1.52624903e-01 5.57840908e-01 2.01939101e-01
#  1.06436091e+00 3.93503306e-01 3.16962505e-01 9.72582994e-02
#  2.10030504e-01 5.67366990e-02 4.52034507e-01 2.21000952e+00
#  3.83349840e-03 2.22412104e-01 7.22178510e-01 7.98719310e-01
#  2.15446301e-01 1.53017018e-02 1.15215771e+00 1.61629703e-01
#  5.31952107e-01 1.01760699e-01 2.25788904e-01 4.81087904e-01
#  3.91252106e-01 3.21464905e-01 1.23359303e-01 1.29264551e+00
#  4.21643306e-01 2.61808105e-01 6.58019309e-01 1.13752491e+00
#  1.19471831e+00 1.68383303e-01 2.75103101e-01 1.41983831e+00
#  9.86482309e-01 1.96523304e-01 8.15603311e-01 1.06886331e+00
#  1.69110792e+00 1.10825931e+00 6.49927905e-01 3.33113020e-02
#  2.05129992e+00 7.45603907e-01 9.61931312e-01 3.20616553e+00
# ...

# %%
threshold_z = 10

outlier_indices = np.where(z > threshold_z)[0]
no_outliers = df.drop(outlier_indices)
print("Original DataFrame Shape:", df.shape)
print("DataFrame Shape after Removing Outliers:", no_outliers.shape)
# Out:
# Original DataFrame Shape: (244, 7)
# DataFrame Shape after Removing Outliers: (244, 7)
